# %% [markdown]
# Variables i tipus de dades

# %%
nom = "Anna"
edat = 19
altura = 1.72
print(nom, edat, altura)
# Out:
# Ana 19 1.72

# %%
Operadores

Matemáticos: + - * / // % **

Cadenas: "Hola " + "Mundo"

Comparación: ==, <, >, !=

# %% [markdown]
# Suma de dues edats

# %%
edat1 = 15
edat2 = 20
suma = edat1 + edat2
print("La suma de les edats és:", suma)
# Out:
# La suma de les edats és: 35

# %% [markdown]
# Crea una variable metres amb un valor decimal i calcula quants centímetres són

# %%
metres = 1.75
centimetres = metres * 100
print(metres, "metres són", centimetres, "centímetres")
# Out:
# 1.75 metres són 175.0 centímetres

# %% [markdown]
# Crea dues variables nom i cognom amb el teu nom i cognom. Mostra-les juntes en una sola frase.

# %%
nom = "Anna"
cognom = "Pérez"
print("El teu nom complet és:", nom + " " + cognom)
# Out:
# El teu nom complet és: Anna Pérez

# %% [markdown]
# Crea dues variables nota1 i nota2. Calcula la diferència absoluta entre les dues notes

# %% [markdown]
# Crea tres variables amb valors numèrics i calcula el seu promig.

# %% [markdown]
# Crea dues variables a i b i intercanvia els seus valors. Mostra el resultat

# %% [markdown]
# Crea dues variables dividend i divisor. Calcula el quocient enter i el residu de la divisió.
